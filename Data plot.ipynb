# %%
import numpy as np
import pandas as pd

artist=pd.read_csv("artists.csv",index_col='Artist ID')
artist.head(5)
# Out:
#                       Name Nationality Gender  Birth Year  Death Year
# Artist ID
# 1           Robert Arneson    American   Male      1930.0      1992.0
# 2           Doroteo Arnaiz     Spanish   Male      1936.0         NaN
# 3              Bill Arnold    American   Male      1941.0         NaN
# 4          Charles Arnoldi    American   Male      1946.0         NaN
# 5              Per Arnoldi      Danish   Male      1941.0         NaN

# %%
art_work=pd.read_csv("artworks.csv",index_col='Artwork ID')
art_work.head(5)
# Out:
#                                                         Title Artist ID  \
# Artwork ID
# 2           Ferdinandsbrücke Project, Vienna, Austria, Ele...      6210
# 3           City of Music, National Superior Conservatory ...      7470
# 4           Villa near Vienna Project, Outside Vienna, Aus...      7605
# 5           The Manhattan Transcripts Project, New York, N...      7056
# 6           Villa, project, outside Vienna, Austria, Exter...      7605
#
#                                 Name  Date  \
# Artwork ID
# 2                        Otto Wagner  1896
# 3           Christian de Portzamparc  1987
# 4                         Emil Hoppe  1903
# 5                    Bernard Tschumi  1980
# 6                         Emil Hoppe  1903
#
#                                                        Medium  \
# Artwork ID
# 2               Ink and cut-and-pasted painted pages on paper
# 3                           Paint and colored pencil on print
# ...

# %%
art_work.columns
# Out:
# Index(['Title', 'Artist ID', 'Name', 'Date', 'Medium', 'Dimensions',
#        'Acquisition Date', 'Credit', 'Catalogue', 'Department',
#        'Classification', 'Object Number', 'Diameter (cm)',
#        'Circumference (cm)', 'Height (cm)', 'Length (cm)', 'Width (cm)',
#        'Depth (cm)', 'Weight (kg)', 'Duration (s)'],
#       dtype='object')

# %%
mues_art=pd.concat([artist,art_work],keys='Artist ID')

# %%
mues_art.index_col = 'Artist ID'

# %%
mues_art.
# Out:
# Name                  Doroteo Arnaiz
# Nationality                  Spanish
# Gender                          Male
# Birth Year                      1936
# Death Year                       NaN
# Title                            NaN
# Artist ID                        NaN
# Date                             NaN
# Medium                           NaN
# Dimensions                       NaN
# Acquisition Date                 NaN
# Credit                           NaN
# Catalogue                        NaN
# Department                       NaN
# Classification                   NaN
# Object Number                    NaN
# Diameter (cm)                    NaN
# Circumference (cm)               NaN
# Height (cm)                      NaN
# Length (cm)                      NaN
# Width (cm)                       NaN
# Depth (cm)                       NaN
# Weight (kg)                      NaN
# Duration (s)                     NaN
# Name: (A, 2), dtype: object

# %%
mues_art.head(5)
# Out:
#                 Name Nationality Gender  Birth Year  Death Year Title  \
# A 1   Robert Arneson    American   Male      1930.0      1992.0   NaN
#   2   Doroteo Arnaiz     Spanish   Male      1936.0         NaN   NaN
#   3      Bill Arnold    American   Male      1941.0         NaN   NaN
#   4  Charles Arnoldi    American   Male      1946.0         NaN   NaN
#   5      Per Arnoldi      Danish   Male      1941.0         NaN   NaN
#
#     Artist ID Date Medium Dimensions  ... Classification Object Number  \
# A 1       NaN  NaN    NaN        NaN  ...            NaN           NaN
#   2       NaN  NaN    NaN        NaN  ...            NaN           NaN
#   3       NaN  NaN    NaN        NaN  ...            NaN           NaN
#   4       NaN  NaN    NaN        NaN  ...            NaN           NaN
#   5       NaN  NaN    NaN        NaN  ...            NaN           NaN
#
#     Diameter (cm) Circumference (cm) Height (cm) Length (cm)  Width (cm)  \
# ...

# %%
mues_nat=mues_art['Nationality'].value_counts

# %%
joint_df = pd.concat([artist,art_work],join='inner',keys='Artist ID')

# %%
joint_df.head(5)
# Out:
#                 Name
# A 1   Robert Arneson
#   2   Doroteo Arnaiz
#   3      Bill Arnold
#   4  Charles Arnoldi
#   5      Per Arnoldi

# %%
mues_art['Nationality'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of A  1         American
#    2          Spanish
#    3         American
#    4         American
#    5           Danish
#                ...
# r  217983         NaN
#    217984         NaN
#    217985         NaN
#    217986         NaN
#    218011         NaN
# Name: Nationality, Length: 145353, dtype: object>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

color = sns.color_palette()

# %matplotlib inline

# %%
artists = pd.read_csv('artists.csv',encoding='utf-8')
artworks = pd.read_csv('artworks.csv',encoding='utf-8')
joint_df = pd.concat([artists,artworks],join='inner',keys='Artist ID')

# %%
counts = artworks['Credit'].value_counts()
counts[:20]

count1=artworks['Medium'].value_counts()

# %%
plt.figure(figsize=(10,8))
sns.barplot(counts[:20].values,counts[:20].index)
#     plt.xlabel(column)
plt.xlabel('Number of ArtWorks')
plt.xticks(rotation=0)
plt.title('Medium')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.barplot(count1[:20].values,count1[:20].index)
#     plt.xlabel(column)
plt.xlabel('Number of Artworks')
plt.xticks(rotation=0)
plt.title('Medium')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# Seaborn Settings
sns.set_style(style='white')

# Import data 
df = pd.read_csv("artworks.csv")
df.Classification.unique()
# Out:
# array(['Architecture', 'Mies van der Rohe Archive', 'Design',
#        'Illustrated Book', 'Print', 'Drawing', 'Film', 'Multiple',
#        'Periodical', 'Photograph', 'Painting', 'Product Design',
#        'Photography Research/Reference', 'Media', 'Sculpture', 'Textile',
#        'Installation', 'Video', 'Work on Paper', 'Audio', 'Performance',
#        '(not assigned)', 'Film (object)', 'Ephemera', 'Collage',
#        'Frank Lloyd Wright Archive', 'Furniture and Interiors',
#        'Software'], dtype=object)

# %%
df_drawing = df[df['Classification'] == 'Drawing']
df_painting = df[df['Classification'] == 'Painting']
df_photo = df[df['Classification'] == 'Photograph']


# Concatenate all of artworks
all_2D = [df_painting, df_drawing, df_photo]
df_2d = pd.concat(all_2D,axis=0,ignore_index=True)

# %%
df_2d = df_2d[['Title', 'Classification', 'Height (cm)', 'Width (cm)']]
df_2d = df_2d.rename(columns={'Height (cm)': 'height', 'Width (cm)': 'width'})

# Remove artworks with NaN
df_2d = df_2d.dropna()

# %%
ratio =  np.log10(df_2d['height'])/np.log10(df_2d['width'])
width = np.log10(df_2d['width'])

# 4/3
four_thirds = np.log10(4)/np.log10(3)
three_fourths = np.log10(3)/np.log10(4)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
h = plt.scatter(width,ratio, alpha=0.02, c='c')
plt.axhline(y=1.0, color='k', linestyle='-',linewidth=0.75)
plt.axhline(y=four_thirds, color='r', linestyle='-',linewidth=0.75)
plt.axhline(y=three_fourths, color='r', linestyle='-',linewidth=0.75)
plt.xlim((0.5,3.5))
plt.ylim((0.6,1.4))
plt.title("Dimensions of Artwork")
plt.xlabel('Width')
plt.ylabel('Height')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
